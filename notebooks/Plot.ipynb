# %%
from pylab import figure, axes, pie, title, show
import matplotlib.pyplot as plt
# Make a square figure and axes
figure(1, figsize=(6, 6))
ax = axes([0.1, 0.1, 0.8, 0.8])

labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
fracs = [15, 30, 45, 10]

explode = (0, 0.05, 0, 0)
pie(fracs, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True)
title('Raining Hogs and Dogs', bbox={'facecolor': '0.8', 'pad': 5})

#plt.show()  # Actually, don't show, just save to foo.png
plt.savefig("example.png")

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="ticks")

# Create a dataset with many short random walks
rs = np.random.RandomState(4)
pos = rs.randint(-1, 2, (20, 5)).cumsum(axis=1)
pos -= pos[:, 0, np.newaxis]
step = np.tile(range(5), 20)
walk = np.repeat(range(20), 5)
df = pd.DataFrame(np.c_[pos.flat, step, walk],
                  columns=["position", "step", "walk"])

df
# Out:
#     position  step  walk
# 0          0     0     0
# 1          1     1     0
# 2          1     2     0
# 3          1     3     0
# 4          0     4     0
# 5          0     0     1
# 6          1     1     1
# 7          1     2     1
# 8          2     3     1
# 9          1     4     1
# 10         0     0     2
# 11         1     1     2
# 12         1     2     2
# 13         0     3     2
# 14        -1     4     2
# 15         0     0     3
# 16        -1     1     3
# 17         0     2     3
# 18         1     3     3
# 19         2     4     3
# 20         0     0     4
# 21        -1     1     4
# 22        -1     2     4
# 23        -1     3     4
# 24        -1     4     4
# 25         0     0     5
# 26         0     1     5
# 27         1     2     5
# 28         0     3     5
# 29         1     4     5
# ..       ...   ...   ...
# 70         0     0    14
# 71         0     1    14
# 72         1     2    14
# 73         0     3    14
# 74        -1     4    14
# ...

# %%
# Initialize a grid of plots with an Axes for each walk
grid = sns.FacetGrid(df, col="walk", hue="walk", col_wrap=5, size=1.5)

# Draw a horizontal line to show the starting point
grid.map(plt.axhline, y=0, ls=":", c=".5")

# Draw a line plot to show the trajectory of each random walk
grid.map(plt.plot, "step", "position", marker="o", ms=4)

# Adjust the tick positions and labels
grid.set(xticks=np.arange(5), yticks=[-3, 3],
         xlim=(-.5, 4.5), ylim=(-3.5, 3.5))

# Adjust the arrangement of the plots
grid.fig.tight_layout(w_pad=1)

# %%
a = [[1, 2, 3], [4, 5, 6]]
dict( ("a %d" %x, a[x]) for x in range(len(a)) )
# Out:
# {'a 0': [1, 2, 3], 'a 1': [4, 5, 6]}

# %%
import pandas
from pandas import DataFrame as DF
filename="C:\\Users\\baddar\\Dropbox (Personal)\\MSc Project\\BTCWavelet\\Data\\bitcoincharts\\.bitfinexUSD.csv"
df = pandas.read_csv( filename, header=None)
# Out:
#                    0       1         2
# 10182247  1482410597  853.48  0.116000
# 10182248  1482410597  853.48  0.119000
# 10182249  1482410597  853.48  0.118000
# 10182250  1482410597  853.40  2.431919
# 10182251  1482410598  853.48  0.119000

# %%
df.tail()

# %%
class A(object):
    @property
    def endpoint(self):
        return self.__endpoint

    @endpoint.setter
    def endpoint(self, endpoint):
        if endpoint:    
            self.__endpoint = endpoint
            
    def __init__(self, symbol= None , startTime = None, limit = None ):
        self.endpoint = 'blah'
        pass
    def foo(self, text):
        return text
class B(A):
    
    pass

# %%
b = B()
b.foo(b.endpoint)
# Out:
# 'blah'

# %%
b.endpoint
# Out:
# 'blah'

# %%
import requests
r = requests.post('http://httpbin.org/post', data = {'blah':'10'})
b = r.json()
b
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'blah': '10'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Connection': 'close',
#   'Content-Length': '7',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.18.4'},
#  'json': None,
#  'origin': '161.23.70.148',
#  'url': 'http://httpbin.org/post'}

# %%
def md5_encode( s = "accesskey=zhangsan&num=50&secretkey=zhangsan&symbol=BTC/USD&timestamp=1500000000000"):
    import hashlib
    m = hashlib.md5()
    #hash_string = "accesskey=zhangsan&num=50&secretkey=zhangsan&symbol=BTC/USD&timestamp=1500000000000"
    m.update(s.encode("utf8"))
    return m.hexdigest()
md5_encode()
# Out:
# '394d7dddedc00546ed21d371a479709d'

# %%
endpoint = "https://api.coinsuper.com/"

# %%
import json
import os
import time
import urllib.error
import urllib.parse as urlparse
import urllib.request
import urllib.response
from datetime import datetime
from urllib.parse import urlencode
import requests

import numpy as np
import pandas as pd
from lxml import html
from pandas import DataFrame as DF

# %%
def get_API ( full_url):
    formatted_json = "error"
    try: 
        res = urllib.request.urlopen( full_url)
        b = res.read() #read resonse bytes
        json_string = b.decode('utf8').replace("'", '"')
        json_data = json.loads(json_string)
        formatted_json = json.dumps( json_data , indent=4, sort_keys=True)
    except urllib.error.URLError as e:
        print(e.reason)
    return formatted_json

resp = requests.get("https://api.bitfinex.com/v1/symbols")
j = resp.json()

j = [x for x in j if x.lower().find('btc')>=0 ]
j
# f = filter(lambda x: x.find('btc')>=0 , j ) 
# for x in f:
#     print(x)
# Out:
# ['btcusd',
#  'ltcbtc',
#  'ethbtc',
#  'etcbtc',
#  'rrtbtc',
#  'zecbtc',
#  'xmrbtc',
#  'dshbtc',
#  'btceur',
#  'btcjpy',
#  'xrpbtc',
#  'iotbtc',
#  'eosbtc',
#  'sanbtc',
#  'omgbtc',
#  'bchbtc',
#  'neobtc',
#  'etpbtc',
#  'qtmbtc',
#  'avtbtc',
#  'edobtc',
#  'btgbtc',
#  'datbtc',
#  'qshbtc',
#  'yywbtc',
#  'gntbtc',
#  'sntbtc',
#  'batbtc',
#  'mnabtc',
#  'funbtc',
#  'zrxbtc',
#  'tnbbtc',
#  'spkbtc',
#  'trxbtc',
#  'rcnbtc',
#  'rlcbtc',
#  'aidbtc',
#  'sngbtc',
#  'repbtc',
#  'elfbtc',
#  'btcgbp',
#  'iosbtc',
#  'aiobtc',
#  'reqbtc',
#  'rdnbtc',
#  'lrcbtc',
#  'waxbtc',
#  'daibtc',
#  'cfibtc',
#  'agibtc',
#  'bftbtc',
#  'mtnbtc',
#  'odebtc',
#  'antbtc',
#  'dthbtc',
#  'mitbtc',
#  'stjbtc',
#  'xlmbtc',
#  'xvgbtc',
#  'bcibtc',
#  'mkrbtc',
#  'venbtc',
#  'kncbtc',
#  'poabtc',
#  'lymbtc',
#  'utkbtc',
#  'veebtc',
#  'dadbtc',
#  'orsbtc',
#  'aucbtc',
#  'poybtc',
#  'fsnbtc',
#  'cbtbtc',
#  'zcnbtc',
#  'senbtc',
#  'ncabtc',
# ...

# %%
from datetime import datetime
date_format = "%m/%d/%Y"
a = datetime.strptime('1/1/2017', date_format)
b = datetime.strptime('7/18/2018', date_format)
delta = b - a
print( delta.days) # that's it
# Out:
# 563

# %%
def get_days_between ( date1, date2):
    date_format = "%B %d, %Y"
    delta = datetime.strptime( date2, date_format) - datetime.strptime( date1, date_format)
    return delta.days

get_days_between( "July 18, 2018", "January 1, 2017")
# Out:
# -563

# %%
data = {}
data ['btc'] = [1,2]
data ['bla'] = [3, 4, 5]
data
# Out:
# {'bla': [3, 4, 5], 'btc': [1, 2]}

# %%
import time, numpy as np
np.round(time.time())
# Out:
# 1531906598.0

# %%
for i in range(1,3):
    print(i)
# Out:
# 1
# 2

# %%
for a,b in [(1,2),(2,3) ,(3,4)]:
    print (a,b)
# Out:
# 1 2
# 2 3
# 3 4

# %%
symbols = [1,2,3]
for idx, val in enumerate(symbols):
    print(idx, val)
# Out:
# 0 1
# 1 2
# 2 3

# %%
from pandas_datareader import data as pdr
import fix_yahoo_finance

data = pdr.get_data_yahoo('APPL', start='2017-04-23', end='2017-05-24')
cols = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close']
data.reindex(columns=cols)
# Out:
# ---------------------------------------------------------------------------
# ImmediateDeprecationError                 Traceback (most recent call last)
# <ipython-input-29-b7855759a9b8> in <module>()
#       2 import fix_yahoo_finance
#       3
# ----> 4 data = pdr.get_data_yahoo('APPL', start='2017-04-23', end='2017-05-24')
#       5 cols = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close']
#       6 data.reindex(columns=cols)
#
# ~\Anaconda3\envs\Tensorflow\lib\site-packages\pandas_datareader\data.py in get_data_yahoo(*args, **kwargs)
#      61
#      62 def get_data_yahoo(*args, **kwargs):
# ---> 63     raise ImmediateDeprecationError(DEP_ERROR_MSG.format('Yahoo Actions'))
#      64     return YahooDailyReader(*args, **kwargs).read()
#      65
#
# ImmediateDeprecationError:
# Yahoo Actions has been immediately deprecated due to large breaks in the API without the
# introduction of a stable replacement. Pull Requests to re-enable these data
# connectors are welcome.
# ...

# %%
import pandas as pd
import numpy as np
from datetime import datetime
#import pandas.DataFrame as DF
daily_data = pd.read_csv( "../Data/Stock/NASDAQCOM.csv", sep=',', index_col = 0, names=['Close'], header=None )
num_days = len(daily_data)
timeseries = range(0, num_days)
values = [daily_data['Close'][i] for i in range(num_days)]
datetimes = map(lambda tm: datetime.strptime( tm, "%Y-%m-%d") , daily_data.index.tolist())
def fl(x):
    try:
        x=float(x)
    except ValueError:
        x=np.nan
daily_data['Close'] = daily_data['Close'].apply( lambda x: np.nan if x=='.' else float(x) ).apply( lambda x: np.log(x) )

daily_data = daily_data [  np.isnan(daily_data['Close'])==False  ]
# a = 'a'
# if type(a) == str:
#     print("str")
#daily_data
# Out:
#                Close
# 1971-02-05  4.605170
# 1971-02-08  4.613535
# 1971-02-09  4.612741
# 1971-02-10  4.612046
# 1971-02-11  4.619566
# 1971-02-12  4.625463
# 1971-02-16  4.626834
# 1971-02-17  4.622421
# 1971-02-18  4.619270
# 1971-02-19  4.612146
# 1971-02-22  4.601965
# 1971-02-23  4.602366
# 1971-02-24  4.611550
# 1971-02-25  4.617395
# 1971-02-26  4.618481
# 1971-03-01  4.622814
# 1971-03-02  4.623403
# 1971-03-03  4.625659
# 1971-03-04  4.632591
# 1971-03-05  4.639668
# 1971-03-08  4.646600
# 1971-03-09  4.648325
# 1971-03-10  4.645736
# 1971-03-11  4.646888
# 1971-03-12  4.649187
# 1971-03-15  4.655198
# 1971-03-16  4.659280
# 1971-03-17  4.658711
# 1971-03-18  4.662306
# 1971-03-19  4.661267
# ...              ...
# 2018-05-30  8.917639
# 2018-05-31  8.914911
# 2018-06-01  8.929876
# 2018-06-04  8.936753
# 2018-06-05  8.940873
# 2018-06-06  8.947577
# 2018-06-07  8.940507
# 2018-06-08  8.941874
# 2018-06-11  8.943758
# 2018-06-12  8.949468
# 2018-06-13  8.948417
# ...

# %%
df = pd.DataFrame({'a': [100, 1000], 'b': [200, 2000], 'c': [300, 3000]})
df[a].apply(lambda x: int(x))
# Out:
# 0     100
# 1    1000
# Name: a, dtype: int64

# %%
d={'a': 1, 'b': 2}
1 in d
# Out:
# False
